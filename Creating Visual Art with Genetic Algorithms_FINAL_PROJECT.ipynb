# %%
import random


class Triangle:
    def __init__(self, img_width, img_height):
        x = random.randint(0, int(img_width))
        y = random.randint(0, int(img_height))

        self.points = [
            (x + random.randint(-50, 50), y + random.randint(-50, 50)),
            (x + random.randint(-50, 50), y + random.randint(-50, 50)),
            (x + random.randint(-50, 50), y + random.randint(-50, 50))]
        self.color = (
            random.randint(0, 256),
            random.randint(0, 256),
            random.randint(0, 256),
            random.randint(0, 256)
        )

        self._img_width = img_width
        self._img_height = img_height

    def __repr__(self):
        return "Trangle: %s in color %s" % (','.join([str(p) for p in self.points]), str(self.color))

    def mutate(self, sigma=1.0):
        mutations = ['shift', 'point', 'color', 'reset']
        weights = [30, 35, 30, 5]

        mutation_type = random.choices(mutations, weights=weights, k=1)[0]

        if mutation_type == 'shift':
            x_shift = int(random.randint(-50, 50)*sigma)
            y_shift = int(random.randint(-50, 50)*sigma)
            self.points = [(x + x_shift, y + y_shift) for x, y in self.points]
        elif mutation_type == 'point':
            index = random.choice(list(range(len(self.points))))

            self.points[index] = (self.points[index][0] + int(random.randint(-50, 50)*sigma),
                                  self.points[index][1] + int(random.randint(-50, 50)*sigma),)
        elif mutation_type == 'color':
            self.color = tuple(
                c + int(random.randint(-50, 50)*sigma) for c in self.color
            )

            # Ensure color is within correct range
            self.color = tuple(
                min(max(c, 0), 255) for c in self.color
            )
        else:
            new_triangle = Triangle(self._img_width, self._img_height)

            self.points = new_triangle.points
            self.color = new_triangle.color

# %%
# !pip install triangle
# Out:
# Collecting triangle
#   Downloading triangle-20230923-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from triangle) (1.25.2)
# Installing collected packages: triangle
# Successfully installed triangle-20230923

# %%
# !pip install imgcompare
# Out:
# Collecting imgcompare
#   Downloading imgcompare-2.0.1-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: pillow>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from imgcompare) (9.4.0)
# Installing collected packages: imgcompare
# Successfully installed imgcompare-2.0.1

# %%
from random import shuffle, randint
from PIL import Image, ImageDraw
from imgcompare import image_diff
import random


class Painting:
    def __init__(self, num_triangles, target_image, background_color=(0, 0, 0)):
        self._img_width, self._img_height = target_image.size
        self.triangles = [Triangle(self._img_width, self._img_height) for _ in range(num_triangles)]
        self._background_color = (*background_color, 255)
        self.target_image = target_image

    @property
    def get_background_color(self):
        return self._background_color[:3]

    @property
    def get_img_width(self):
        return self._img_width

    @property
    def get_img_height(self):
        return self._img_height

    @property
    def num_triangles(self):
        return len(self.triangles)

    def __repr__(self):
        return "Painting with %d triangles" % self.num_triangles

    def mutate_triangles(self, rate=0.04, swap=0.5, sigma=1.0):
        total_mutations = int(rate*self.num_triangles)
        random_indices = list(range(self.num_triangles))
        shuffle(random_indices)

        # mutate random triangles
        for i in range(total_mutations):
            index = random_indices[i]
            self.triangles[index].mutate(sigma=sigma)

        # Swap two triangles randomly
        if random.random() < swap:
            shuffle(random_indices)
            self.triangles[random_indices[0]], self.triangles[random_indices[1]] = self.triangles[random_indices[1]], self.triangles[random_indices[0]]

    def draw(self, scale=1) -> Image:
        image = Image.new("RGBA", (self._img_width*scale, self._img_height*scale))
        draw = ImageDraw.Draw(image)

        if not hasattr(self, '_background_color'):
            self._background_color = (0, 0, 0, 255)

        draw.polygon([(0, 0), (0, self._img_height*scale), (self._img_width*scale, self._img_height*scale), (self._img_width*scale, 0)],
                     fill=self._background_color)

        for t in self.triangles:
            new_triangle = Image.new("RGBA", (self._img_width*scale, self._img_height*scale))
            tdraw = ImageDraw.Draw(new_triangle)
            tdraw.polygon([(x*scale, y*scale) for x, y in t.points], fill=t.color)

            image = Image.alpha_composite(image, new_triangle)

        return image

    @staticmethod
    def _mate_possible(a, b) -> bool:
        return all([a.num_triangles == b.num_triangles,
                   a.get_img_width == b.get_img_width,
                   a.get_img_height == b.get_img_height])

    @staticmethod
    def mate(a, b):
        if not Painting._mate_possible(a, b):
            raise Exception("Cannot mate images with different dimensions or number of triangles")

        ab = a.get_background_color
        bb = b.get_background_color
        new_background = (int((ab[i] + bb[i])/2) for i in range(3))

        child_a = Painting(0, a.target_image, background_color=new_background)
        child_b = Painting(0, a.target_image, background_color=new_background)

        for at, bt in zip(a.triangles, b.triangles):
            if randint(0, 1) == 0:
                child_a.triangles.append(at)
                child_b.triangles.append(bt)
            else:
                child_a.triangles.append(bt)
                child_b.triangles.append(at)

        return child_a, child_b

    def image_diff(self, target: Image) -> float:
        source = self.draw()

        return image_diff(source, target)

# %%
# !pip install evol
# Out:
# Collecting evol
#   Downloading evol-0.5.3-py2.py3-none-any.whl (34 kB)
# Collecting multiprocess>=0.70.6.1 (from evol)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.9 MB/s eta 0:00:00
# Collecting dill>=0.3.8 (from multiprocess>=0.70.6.1->evol)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: dill, multiprocess, evol
# Successfully installed dill-0.3.8 evol-0.5.3 multiprocess-0.70.16

# %%
from PIL import Image
from evol import Evolution, Population

import random
import os
from copy import deepcopy


def score(x: Painting) -> float:
    """
    Calculate the distance to the target image

    :param x: a Painting object to calculate the distance for
    :return: distance based on pixel differences
    """
    current_score = x.image_diff(x.target_image)
    print(".", end='', flush=True)
    return current_score


def pick_best_and_random(pop, maximize=False):
    """
    Here we select the best individual from a population and pair it with a random individual from a population

    :param pop: input population
    :param maximize: when true a higher fitness score is better, otherwise a lower score is considered better
    :return: a tuple with the best and a random individual
    """
    evaluated_individuals = tuple(filter(lambda x: x.fitness is not None, pop))
    if len(evaluated_individuals) > 0:
        mom = max(evaluated_individuals, key=lambda x: x.fitness if maximize else -x.fitness)
    else:
        mom = random.choice(pop)
    dad = random.choice(pop)
    return mom, dad


def mutate_painting(x: Painting, rate=0.04, swap=0.5, sigma=1) -> Painting:
    """
    This will mutate a painting by randomly applying changes to the triangles.

    :param x: Painting to mutate
    :param rate: the chance a triangle will be mutated
    :param swap: the chance a pair of traingles will be swapped
    :param sigma: the strenght of the mutation (how much a triangle can be changed)
    :return: New painting object with mutations
    """
    x.mutate_triangles(rate=rate, swap=swap, sigma=sigma)
    return deepcopy(x)


def mate(mom: Painting, dad: Painting):
    """
    Takes two paintings, the mom and dad, to create a new painting object made up with triangles from both parents

    :param mom: One parent painting
    :param dad: Other parent painting
    :return: new Painting with features from both parents
    """
    child_a, child_b = Painting.mate(mom, dad)

    return deepcopy(child_a)


def print_summary(pop, img_template="output%d.png", checkpoint_path="output") -> Population:
    """
    This will print a summary of the population fitness and store an image of the best individual of the current
    generation. Every fifty generations the entire population is stored.

    :param pop: Population
    :param img_template: a template for the name of the output images, should contain %d as the number of the generation is included
    :param checkpoint_path: directory to write output.
    :return: The input population
    """
    avg_fitness = sum([i.fitness for i in pop.individuals])/len(pop.individuals)

    print("\nCurrent generation %d, best score %f, pop. avg. %f " % (pop.generation,
                                                                     pop.current_best.fitness,
                                                                     avg_fitness))
    img = pop.current_best.chromosome.draw()
    img.save(img_template % pop.generation, 'PNG')

    if pop.generation % 50 == 0:
        pop.checkpoint(target=checkpoint_path, method='pickle')

    return pop


if __name__ == "__main__":
    target_image_path = "/content/AB.png"
    checkpoint_path = "/content/starry_night"
    image_template = os.path.join(checkpoint_path, "drawing_%05d.png")
    target_image = Image.open(target_image_path).convert('RGBA')

    num_triangles = 20
    population_size = 50

    pop = Population(chromosomes=[Painting(num_triangles, target_image, background_color=(255, 255, 255)) for _ in range(population_size)],
                     eval_function=score, maximize=False, concurrent_workers=6)

    evolution = (Evolution()
                 .survive(fraction=0.05)
                 .breed(parent_picker=pick_best_and_random, combiner=mate, population_size=population_size)
                 .mutate(mutate_function=mutate_painting, rate=0.05, swap=0.25)
                 .evaluate(lazy=False)
                 .callback(print_summary,
                           img_template=image_template,
                           checkpoint_path=checkpoint_path))

    pop = pop.evolve(evolution, n=500)
# Out:
# ....................................................................................................
# Current generation 1, best score 4324306.000000, pop. avg. 4667157.880000
# ..................................................
# Current generation 2, best score 4210471.000000, pop. avg. 4339372.160000
# ..................................................
# Current generation 3, best score 4084902.000000, pop. avg. 4258042.020000
# ..................................................
# Current generation 4, best score 3953356.000000, pop. avg. 4103241.180000
# ..................................................
# Current generation 5, best score 3892894.000000, pop. avg. 3983571.000000
# ..................................................
# Current generation 6, best score 3774544.000000, pop. avg. 3912790.160000
# ..................................................
# Current generation 7, best score 3644140.000000, pop. avg. 3798632.560000
# ..................................................
# Current generation 8, best score 3424985.000000, pop. avg. 3685091.280000
# ..................................................
# Current generation 9, best score 3348477.000000, pop. avg. 3484046.900000
# ..................................................
# Current generation 10, best score 3314451.000000, pop. avg. 3371234.900000
# ..................................................
# Current generation 11, best score 3212196.000000, pop. avg. 3361263.660000
# ..................................................
# Current generation 12, best score 3147368.000000, pop. avg. 3236927.780000
# ..................................................
# Current generation 13, best score 3064299.000000, pop. avg. 3163796.660000
# ..................................................
# Current generation 14, best score 2997107.000000, pop. avg. 3111644.340000
# ..................................................
# Current generation 15, best score 2845308.000000, pop. avg. 3027604.940000
# ..................................................
# Current generation 16, best score 2825551.000000, pop. avg. 2873526.180000
# ..................................................
# Current generation 17, best score 2801622.000000, pop. avg. 2855133.200000
# ..................................................
# Current generation 18, best score 2774831.000000, pop. avg. 2841055.260000
# ..................................................
# Current generation 19, best score 2754653.000000, pop. avg. 2807616.400000
# ..................................................
# Current generation 20, best score 2734038.000000, pop. avg. 2776743.580000
# ..................................................
# Current generation 21, best score 2640197.000000, pop. avg. 2763467.020000
# ..................................................
# Current generation 22, best score 2610834.000000, pop. avg. 2687430.100000
# ..................................................
# Current generation 23, best score 2595209.000000, pop. avg. 2635182.180000
# ..................................................
# Current generation 24, best score 2568207.000000, pop. avg. 2617685.940000
# ..................................................
# Current generation 25, best score 2550253.000000, pop. avg. 2626150.960000
# ..................................................
# Current generation 26, best score 2535592.000000, pop. avg. 2582507.920000
# ..................................................
# Current generation 27, best score 2518654.000000, pop. avg. 2567116.420000
# ..................................................
# Current generation 28, best score 2487973.000000, pop. avg. 2556596.640000
# ..................................................
# Current generation 29, best score 2442410.000000, pop. avg. 2509033.720000
# ..................................................
# Current generation 30, best score 2419615.000000, pop. avg. 2498360.520000
# ..................................................
# Current generation 31, best score 2363060.000000, pop. avg. 2447083.980000
# ..................................................
# Current generation 32, best score 2332618.000000, pop. avg. 2403349.140000
# ..................................................
# Current generation 33, best score 2312056.000000, pop. avg. 2372837.580000
# ..................................................
# Current generation 34, best score 2295451.000000, pop. avg. 2368188.040000
# ..................................................
# Current generation 35, best score 2279042.000000, pop. avg. 2320215.900000
# ..................................................
# Current generation 36, best score 2259738.000000, pop. avg. 2318462.980000
# ..................................................
# Current generation 37, best score 2231330.000000, pop. avg. 2276492.620000
# ..................................................
# Current generation 38, best score 2216169.000000, pop. avg. 2281506.320000
# ..................................................
# Current generation 39, best score 2214272.000000, pop. avg. 2265954.320000
# ..................................................
# Current generation 40, best score 2203383.000000, pop. avg. 2255297.440000
# ..................................................
# Current generation 41, best score 2198709.000000, pop. avg. 2254122.460000
# ..................................................
# Current generation 42, best score 2180360.000000, pop. avg. 2250955.740000
# ..................................................
# Current generation 43, best score 2177095.000000, pop. avg. 2232636.600000
# ..................................................
# Current generation 44, best score 2164134.000000, pop. avg. 2210518.800000
# ..................................................
# Current generation 45, best score 2157546.000000, pop. avg. 2200794.820000
# ..................................................
# Current generation 46, best score 2144811.000000, pop. avg. 2196190.160000
# ..................................................
# Current generation 47, best score 2141466.000000, pop. avg. 2195459.820000
# ..................................................
# Current generation 48, best score 2132200.000000, pop. avg. 2183379.320000
# ..................................................
# Current generation 49, best score 2120961.000000, pop. avg. 2165506.020000
# ..................................................
# Current generation 50, best score 2106910.000000, pop. avg. 2160592.700000
# ..................................................
# Current generation 51, best score 2101950.000000, pop. avg. 2142410.880000
# ..................................................
# Current generation 52, best score 2100153.000000, pop. avg. 2146062.360000
# ..................................................
# Current generation 53, best score 2098125.000000, pop. avg. 2122597.740000
# ..................................................
# Current generation 54, best score 2094173.000000, pop. avg. 2143917.140000
# ..................................................
# Current generation 55, best score 2091340.000000, pop. avg. 2150742.280000
# ..................................................
# Current generation 56, best score 2084212.000000, pop. avg. 2121411.820000
# ..................................................
# Current generation 57, best score 2074998.000000, pop. avg. 2146086.460000
# ..................................................
# Current generation 58, best score 2066678.000000, pop. avg. 2121413.220000
# ..................................................
# Current generation 59, best score 2058548.000000, pop. avg. 2085095.900000
# ..................................................
# Current generation 60, best score 2056118.000000, pop. avg. 2105066.720000
# ..................................................
# Current generation 61, best score 2049086.000000, pop. avg. 2093290.360000
# ..................................................
# Current generation 62, best score 2041531.000000, pop. avg. 2093229.160000
# ..................................................
# Current generation 63, best score 2038464.000000, pop. avg. 2078796.680000
# ..................................................
# Current generation 64, best score 2032413.000000, pop. avg. 2069557.800000
# ..................................................
# Current generation 65, best score 2027217.000000, pop. avg. 2081403.980000
# ..................................................
# Current generation 66, best score 2017629.000000, pop. avg. 2084445.640000
# ..................................................
# Current generation 67, best score 2010385.000000, pop. avg. 2065691.800000
# ..................................................
# Current generation 68, best score 2002919.000000, pop. avg. 2047421.080000
# ..................................................
# Current generation 69, best score 1995301.000000, pop. avg. 2028941.140000
# ..................................................
# Current generation 70, best score 1992632.000000, pop. avg. 2033566.220000
# ..................................................
# Current generation 71, best score 1988306.000000, pop. avg. 2024949.660000
# ..................................................
# Current generation 72, best score 1980976.000000, pop. avg. 2045486.820000
# ..................................................
# Current generation 73, best score 1975452.000000, pop. avg. 2017471.160000
# ..................................................
# Current generation 74, best score 1960107.000000, pop. avg. 2018432.540000
# ..................................................
# Current generation 75, best score 1958550.000000, pop. avg. 2002964.720000
# ..................................................
# Current generation 76, best score 1956939.000000, pop. avg. 1985649.060000
# ..................................................
# Current generation 77, best score 1953334.000000, pop. avg. 2021801.200000
# ..................................................
# Current generation 78, best score 1951166.000000, pop. avg. 2001991.920000
# ..................................................
# Current generation 79, best score 1947326.000000, pop. avg. 2005975.080000
# ..................................................
# Current generation 80, best score 1931742.000000, pop. avg. 2004181.580000
# ..................................................
# Current generation 81, best score 1917894.000000, pop. avg. 2072165.600000
# ..................................................
# Current generation 82, best score 1913988.000000, pop. avg. 2012599.980000
# ..................................................
# Current generation 83, best score 1911063.000000, pop. avg. 1968613.100000
# ..................................................
# Current generation 84, best score 1909911.000000, pop. avg. 1986139.720000
# ..................................................
# Current generation 85, best score 1909170.000000, pop. avg. 1951280.100000
# ..................................................
# Current generation 86, best score 1899932.000000, pop. avg. 1948388.520000
# ..................................................
# Current generation 87, best score 1894192.000000, pop. avg. 1965542.560000
# ..................................................
# Current generation 88, best score 1880795.000000, pop. avg. 1936834.720000
# ..................................................
# Current generation 89, best score 1875129.000000, pop. avg. 1954421.100000
# ..................................................
# Current generation 90, best score 1872114.000000, pop. avg. 1936140.840000
# ..................................................
# Current generation 91, best score 1866373.000000, pop. avg. 1923260.820000
# ..................................................
# Current generation 92, best score 1858004.000000, pop. avg. 1928515.120000
# ..................................................
# Current generation 93, best score 1853154.000000, pop. avg. 1905614.080000
# ..................................................
# Current generation 94, best score 1850139.000000, pop. avg. 1899475.880000
# ..................................................
# Current generation 95, best score 1845450.000000, pop. avg. 1926934.040000
# ..................................................
# Current generation 96, best score 1839456.000000, pop. avg. 1898128.900000
# ..................................................
# Current generation 97, best score 1833407.000000, pop. avg. 1919571.240000
# ..................................................
# Current generation 98, best score 1829668.000000, pop. avg. 1884418.860000
# ..................................................
# Current generation 99, best score 1816809.000000, pop. avg. 1895029.560000
# ..................................................
# Current generation 100, best score 1811112.000000, pop. avg. 1868070.880000
# ..................................................
# Current generation 101, best score 1801354.000000, pop. avg. 1852957.320000
# ..................................................
# Current generation 102, best score 1793506.000000, pop. avg. 1844328.020000
# ..................................................
# Current generation 103, best score 1787982.000000, pop. avg. 1829575.120000
# ..................................................
# Current generation 104, best score 1780956.000000, pop. avg. 1849624.280000
# ..................................................
# Current generation 105, best score 1779669.000000, pop. avg. 1873169.100000
# ..................................................
# Current generation 106, best score 1779669.000000, pop. avg. 1860897.400000
# ..................................................
# Current generation 107, best score 1776086.000000, pop. avg. 1818233.920000
# ..................................................
# Current generation 108, best score 1770351.000000, pop. avg. 1821108.300000
# ..................................................
# Current generation 109, best score 1764065.000000, pop. avg. 1855030.260000
# ..................................................
# Current generation 110, best score 1762667.000000, pop. avg. 1816348.220000
# ..................................................
# Current generation 111, best score 1761700.000000, pop. avg. 1851900.340000
# ..................................................
# Current generation 112, best score 1757089.000000, pop. avg. 1803796.460000
# ..................................................
# Current generation 113, best score 1756039.000000, pop. avg. 1824775.720000
# ..................................................
# Current generation 114, best score 1748841.000000, pop. avg. 1782686.960000
# ..................................................
# Current generation 115, best score 1737160.000000, pop. avg. 1822146.380000
# ..................................................
# Current generation 116, best score 1719106.000000, pop. avg. 1815636.460000
# ..................................................
# Current generation 117, best score 1715428.000000, pop. avg. 1819418.780000
# ..................................................
# Current generation 118, best score 1713659.000000, pop. avg. 1774529.900000
# ..................................................
# Current generation 119, best score 1708847.000000, pop. avg. 1770309.680000
# ..................................................
# Current generation 120, best score 1706819.000000, pop. avg. 1771493.680000
# ..................................................
# Current generation 121, best score 1702520.000000, pop. avg. 1765120.900000
# ..................................................
# Current generation 122, best score 1691385.000000, pop. avg. 1776531.380000
# ..................................................
# Current generation 123, best score 1690540.000000, pop. avg. 1769540.740000
# ..................................................
# Current generation 124, best score 1678376.000000, pop. avg. 1758412.760000
# ..................................................
# Current generation 125, best score 1677011.000000, pop. avg. 1749630.480000
# ..................................................
# Current generation 126, best score 1672728.000000, pop. avg. 1741734.520000
# ..................................................
# Current generation 127, best score 1671962.000000, pop. avg. 1741702.960000
# ..................................................
# Current generation 128, best score 1670318.000000, pop. avg. 1719554.060000
# ..................................................
# Current generation 129, best score 1668808.000000, pop. avg. 1726437.340000
# ..................................................
# Current generation 130, best score 1665744.000000, pop. avg. 1737718.580000
# ..................................................
# Current generation 131, best score 1655690.000000, pop. avg. 1809713.000000
# ..................................................
# Current generation 132, best score 1655160.000000, pop. avg. 1749434.380000
# ..................................................
# Current generation 133, best score 1644573.000000, pop. avg. 1705671.100000
# ..................................................
# Current generation 134, best score 1643860.000000, pop. avg. 1727732.940000
# ..................................................
# Current generation 135, best score 1642695.000000, pop. avg. 1684027.480000
# ..................................................
# Current generation 136, best score 1641515.000000, pop. avg. 1700221.760000
# ..................................................
# Current generation 137, best score 1640004.000000, pop. avg. 1710945.500000
# ..................................................
# Current generation 138, best score 1639192.000000, pop. avg. 1679674.420000
# ..................................................
# Current generation 139, best score 1638300.000000, pop. avg. 1705940.420000
# ..................................................
# Current generation 140, best score 1638101.000000, pop. avg. 1721401.160000
# ..................................................
# Current generation 141, best score 1634407.000000, pop. avg. 1710600.060000
# ..................................................
# Current generation 142, best score 1632567.000000, pop. avg. 1678533.880000
# ..................................................
# Current generation 143, best score 1625324.000000, pop. avg. 1687122.140000
# ..................................................
# Current generation 144, best score 1624663.000000, pop. avg. 1694189.760000
# ..................................................
# Current generation 145, best score 1624329.000000, pop. avg. 1690454.480000
# ..................................................
# Current generation 146, best score 1622820.000000, pop. avg. 1684924.280000
# ..................................................
# Current generation 147, best score 1622408.000000, pop. avg. 1671200.520000
# ..................................................
# Current generation 148, best score 1622408.000000, pop. avg. 1671435.600000
# ..................................................
# Current generation 149, best score 1620570.000000, pop. avg. 1683695.780000
# ..................................................
# Current generation 150, best score 1619434.000000, pop. avg. 1696069.940000
# ..................................................
# Current generation 151, best score 1618890.000000, pop. avg. 1692703.140000
# ..................................................
# Current generation 152, best score 1618369.000000, pop. avg. 1676618.500000
# ..................................................
# Current generation 153, best score 1618229.000000, pop. avg. 1685960.940000
# ..................................................
# Current generation 154, best score 1616408.000000, pop. avg. 1700144.560000
# ..................................................
# Current generation 155, best score 1615952.000000, pop. avg. 1658901.520000
# ..................................................
# Current generation 156, best score 1608468.000000, pop. avg. 1691151.220000
# ..................................................
# Current generation 157, best score 1606671.000000, pop. avg. 1669603.820000
# ..................................................
# Current generation 158, best score 1606671.000000, pop. avg. 1753967.120000
# ..................................................
# Current generation 159, best score 1604697.000000, pop. avg. 1641684.340000
# ..................................................
# Current generation 160, best score 1604058.000000, pop. avg. 1648237.140000
# ..................................................
# Current generation 161, best score 1603771.000000, pop. avg. 1696584.960000
# ..................................................
# Current generation 162, best score 1602550.000000, pop. avg. 1660390.440000
# ..................................................
# Current generation 163, best score 1600584.000000, pop. avg. 1688872.440000
# ..................................................
# Current generation 164, best score 1599356.000000, pop. avg. 1681954.620000
# ..................................................
# Current generation 165, best score 1598701.000000, pop. avg. 1754423.720000
# ..................................................
# Current generation 166, best score 1598641.000000, pop. avg. 1714043.480000
# ..................................................
# Current generation 167, best score 1597739.000000, pop. avg. 1631466.360000
# ..................................................
# Current generation 168, best score 1597212.000000, pop. avg. 1676823.960000
# ..................................................
# Current generation 169, best score 1595520.000000, pop. avg. 1710111.260000
# ..................................................
# Current generation 170, best score 1595119.000000, pop. avg. 1661369.620000
# ..................................................
# Current generation 171, best score 1594139.000000, pop. avg. 1701113.280000
# ..................................................
# Current generation 172, best score 1592562.000000, pop. avg. 1689664.700000
# ..................................................
# Current generation 173, best score 1592525.000000, pop. avg. 1672478.400000
# ..................................................
# Current generation 174, best score 1592192.000000, pop. avg. 1660029.060000
# ..................................................
# Current generation 175, best score 1590050.000000, pop. avg. 1651400.380000
# ..................................................
# Current generation 176, best score 1589656.000000, pop. avg. 1656899.740000
# ..................................................
# Current generation 177, best score 1588788.000000, pop. avg. 1762471.760000
# ..................................................
# Current generation 178, best score 1587984.000000, pop. avg. 1712071.220000
# ..................................................
# Current generation 179, best score 1587872.000000, pop. avg. 1649638.100000
# ..................................................
# Current generation 180, best score 1587486.000000, pop. avg. 1639602.160000
# ..................................................
# Current generation 181, best score 1587351.000000, pop. avg. 1658064.160000
# ..................................................
# Current generation 182, best score 1586924.000000, pop. avg. 1665620.080000
# ..................................................
# Current generation 183, best score 1586721.000000, pop. avg. 1646517.600000
# ..................................................
# Current generation 184, best score 1586419.000000, pop. avg. 1660332.700000
# ..................................................
# Current generation 185, best score 1586392.000000, pop. avg. 1676247.440000
# ..................................................
# Current generation 186, best score 1583464.000000, pop. avg. 1658080.000000
# ..................................................
# Current generation 187, best score 1582674.000000, pop. avg. 1668399.280000
# ..................................................
# Current generation 188, best score 1582674.000000, pop. avg. 1644657.320000
# ..................................................
# Current generation 189, best score 1582674.000000, pop. avg. 1638898.120000
# ..................................................
# Current generation 190, best score 1582204.000000, pop. avg. 1644882.500000
# ..................................................
# Current generation 191, best score 1582708.000000, pop. avg. 1683544.220000
# ..................................................
# Current generation 192, best score 1582708.000000, pop. avg. 1672123.520000
# ..................................................
# Current generation 193, best score 1582126.000000, pop. avg. 1642925.580000
# ..................................................
# Current generation 194, best score 1582126.000000, pop. avg. 1684918.300000
# ..................................................
# Current generation 195, best score 1582004.000000, pop. avg. 1654464.280000
# ..................................................
# Current generation 196, best score 1580959.000000, pop. avg. 1667714.720000
# ..................................................
# Current generation 197, best score 1580153.000000, pop. avg. 1630705.100000
# ..................................................
# Current generation 198, best score 1579821.000000, pop. avg. 1652664.740000
# ..................................................
# Current generation 199, best score 1578951.000000, pop. avg. 1651630.300000
# ..................................................
# Current generation 200, best score 1577999.000000, pop. avg. 1632809.400000
# ..................................................
# Current generation 201, best score 1576930.000000, pop. avg. 1654233.680000
# ..................................................
# Current generation 202, best score 1576341.000000, pop. avg. 1652901.320000
# ..................................................
# Current generation 203, best score 1575602.000000, pop. avg. 1649464.820000
# ..................................................
# Current generation 204, best score 1575375.000000, pop. avg. 1663950.380000
# ..................................................
# Current generation 205, best score 1574653.000000, pop. avg. 1639510.160000
# ..................................................
# Current generation 206, best score 1572649.000000, pop. avg. 1674761.640000
# ..................................................
# Current generation 207, best score 1571942.000000, pop. avg. 1665928.380000
# ..................................................
# Current generation 208, best score 1571695.000000, pop. avg. 1637897.900000
# ..................................................
# Current generation 209, best score 1571087.000000, pop. avg. 1618285.900000
# ..................................................
# Current generation 210, best score 1570695.000000, pop. avg. 1650162.460000
# ..................................................
# Current generation 211, best score 1570210.000000, pop. avg. 1627966.000000
# ..................................................
# Current generation 212, best score 1567497.000000, pop. avg. 1641503.780000
# ..................................................
# Current generation 213, best score 1567355.000000, pop. avg. 1678642.860000
# ..................................................
# Current generation 214, best score 1564124.000000, pop. avg. 1669432.860000
# ..................................................
# Current generation 215, best score 1563123.000000, pop. avg. 1659309.340000
# ..................................................
# Current generation 216, best score 1562910.000000, pop. avg. 1615798.040000
# ..................................................
# Current generation 217, best score 1560205.000000, pop. avg. 1677402.580000
# ..................................................
# Current generation 218, best score 1559810.000000, pop. avg. 1657702.280000
# ..................................................
# Current generation 219, best score 1559354.000000, pop. avg. 1656296.480000
# ..................................................
# Current generation 220, best score 1559344.000000, pop. avg. 1620365.420000
# ..................................................
# Current generation 221, best score 1559100.000000, pop. avg. 1653943.800000
# ..................................................
# Current generation 222, best score 1558421.000000, pop. avg. 1626310.420000
# ..................................................
# Current generation 223, best score 1558172.000000, pop. avg. 1607159.400000
# ..................................................
# Current generation 224, best score 1557331.000000, pop. avg. 1612338.260000
# ..................................................
# Current generation 225, best score 1555947.000000, pop. avg. 1627204.260000
# ..................................................
# Current generation 226, best score 1554031.000000, pop. avg. 1640804.480000
# ..................................................
# Current generation 227, best score 1551037.000000, pop. avg. 1652962.820000
# ..................................................
# Current generation 228, best score 1551037.000000, pop. avg. 1619007.160000
# ..................................................
# Current generation 229, best score 1550606.000000, pop. avg. 1639827.840000
# ..................................................
# Current generation 230, best score 1550433.000000, pop. avg. 1666984.280000
# ..................................................
# Current generation 231, best score 1550086.000000, pop. avg. 1609892.540000
# ..................................................
# Current generation 232, best score 1550086.000000, pop. avg. 1628194.860000
# ..................................................
# Current generation 233, best score 1549886.000000, pop. avg. 1616630.980000
# ..................................................
# Current generation 234, best score 1549594.000000, pop. avg. 1645905.160000
# ..................................................
# Current generation 235, best score 1548201.000000, pop. avg. 1601824.600000
# ..................................................
# Current generation 236, best score 1547313.000000, pop. avg. 1609356.500000
# ..................................................
# Current generation 237, best score 1546921.000000, pop. avg. 1643651.040000
# ..................................................
# Current generation 238, best score 1546624.000000, pop. avg. 1640361.560000
# ..................................................
# Current generation 239, best score 1545272.000000, pop. avg. 1615725.340000
# ..................................................
# Current generation 240, best score 1544476.000000, pop. avg. 1603115.840000
# ..................................................
# Current generation 241, best score 1543844.000000, pop. avg. 1610704.220000
# ..................................................
# Current generation 242, best score 1543476.000000, pop. avg. 1609032.240000
# ..................................................
# Current generation 243, best score 1542859.000000, pop. avg. 1627608.700000
# ..................................................
# Current generation 244, best score 1541133.000000, pop. avg. 1627911.560000
# ..................................................
# Current generation 245, best score 1540759.000000, pop. avg. 1627096.500000
# ..................................................
# Current generation 246, best score 1537121.000000, pop. avg. 1629562.640000
# ..................................................
# Current generation 247, best score 1537069.000000, pop. avg. 1620702.800000
# ..................................................
# Current generation 248, best score 1536665.000000, pop. avg. 1627798.400000
# ..................................................
# Current generation 249, best score 1535953.000000, pop. avg. 1597516.820000
# ..................................................
# Current generation 250, best score 1535294.000000, pop. avg. 1604432.900000
# ..................................................
# Current generation 251, best score 1536731.000000, pop. avg. 1697026.900000
# ..................................................
# Current generation 252, best score 1536124.000000, pop. avg. 1602384.720000
# ..................................................
# Current generation 253, best score 1534806.000000, pop. avg. 1605930.320000
# ..................................................
# Current generation 254, best score 1534734.000000, pop. avg. 1602233.700000
# ..................................................
# Current generation 255, best score 1534562.000000, pop. avg. 1642063.840000
# ..................................................
# Current generation 256, best score 1533641.000000, pop. avg. 1591512.320000
# ..................................................
# Current generation 257, best score 1533658.000000, pop. avg. 1609429.400000
# ..................................................
# Current generation 258, best score 1533658.000000, pop. avg. 1618739.040000
# ..................................................
# Current generation 259, best score 1533615.000000, pop. avg. 1628365.500000
# ..................................................
# Current generation 260, best score 1533670.000000, pop. avg. 1607616.660000
# ..................................................
# Current generation 261, best score 1533455.000000, pop. avg. 1596285.380000
# ..................................................
# Current generation 262, best score 1531562.000000, pop. avg. 1607371.280000
# ..................................................
# Current generation 263, best score 1531142.000000, pop. avg. 1601517.480000
# ..................................................
# Current generation 264, best score 1530855.000000, pop. avg. 1624200.920000
# ..................................................
# Current generation 265, best score 1530484.000000, pop. avg. 1595089.400000
# ..................................................
# Current generation 266, best score 1530123.000000, pop. avg. 1591266.020000
# ..................................................
# Current generation 267, best score 1529960.000000, pop. avg. 1630317.680000
# ..................................................
# Current generation 268, best score 1529960.000000, pop. avg. 1588181.320000
# ..................................................
# Current generation 269, best score 1529940.000000, pop. avg. 1602346.300000
# ..................................................
# Current generation 270, best score 1529937.000000, pop. avg. 1615118.100000
# ..................................................
# Current generation 271, best score 1529689.000000, pop. avg. 1608346.000000
# ..................................................
# Current generation 272, best score 1529577.000000, pop. avg. 1591453.960000
# ..................................................
# Current generation 273, best score 1529039.000000, pop. avg. 1620176.700000
# ..................................................
# Current generation 274, best score 1528484.000000, pop. avg. 1601570.640000
# ..................................................
# Current generation 275, best score 1527687.000000, pop. avg. 1622833.300000
# ..................................................
# Current generation 276, best score 1527162.000000, pop. avg. 1605984.280000
# ..................................................
# Current generation 277, best score 1527046.000000, pop. avg. 1660584.320000
# ..................................................
# Current generation 278, best score 1526851.000000, pop. avg. 1597730.360000
# ..................................................
# Current generation 279, best score 1526780.000000, pop. avg. 1616880.180000
# ..................................................
# Current generation 280, best score 1526555.000000, pop. avg. 1585080.240000
# ..................................................
# Current generation 281, best score 1526267.000000, pop. avg. 1573192.880000
# ..................................................
# Current generation 282, best score 1526098.000000, pop. avg. 1591120.840000
# ..................................................
# Current generation 283, best score 1525713.000000, pop. avg. 1595619.880000
# ..................................................
# Current generation 284, best score 1525611.000000, pop. avg. 1575228.620000
# ..................................................
# Current generation 285, best score 1525611.000000, pop. avg. 1597657.360000
# ..................................................
# Current generation 286, best score 1525504.000000, pop. avg. 1661228.800000
# ..................................................
# Current generation 287, best score 1525504.000000, pop. avg. 1608401.460000
# ..................................................
# Current generation 288, best score 1525504.000000, pop. avg. 1590030.160000
# ..................................................
# Current generation 289, best score 1525164.000000, pop. avg. 1609848.320000
# ..................................................
# Current generation 290, best score 1522163.000000, pop. avg. 1591508.720000
# ..................................................
# Current generation 291, best score 1522163.000000, pop. avg. 1631959.500000
# ..................................................
# Current generation 292, best score 1522163.000000, pop. avg. 1587877.700000
# ..................................................
# Current generation 293, best score 1522145.000000, pop. avg. 1604691.460000
# ..................................................
# Current generation 294, best score 1522145.000000, pop. avg. 1588677.260000
# ..................................................
# Current generation 295, best score 1522086.000000, pop. avg. 1587405.880000
# ..................................................
# Current generation 296, best score 1521974.000000, pop. avg. 1569464.320000
# ..................................................
# Current generation 297, best score 1521510.000000, pop. avg. 1571852.260000
# ..................................................
# Current generation 298, best score 1521278.000000, pop. avg. 1589847.800000
# ..................................................
# Current generation 299, best score 1521160.000000, pop. avg. 1607140.320000
# ..................................................
# Current generation 300, best score 1520657.000000, pop. avg. 1610355.720000
# ..................................................
# Current generation 301, best score 1520061.000000, pop. avg. 1604110.640000
# ..................................................
# Current generation 302, best score 1520061.000000, pop. avg. 1591750.600000
# ..................................................
# Current generation 303, best score 1520061.000000, pop. avg. 1613289.840000
# ..................................................
# Current generation 304, best score 1520061.000000, pop. avg. 1593789.520000
# ..................................................
# Current generation 305, best score 1518957.000000, pop. avg. 1569019.080000
# ..................................................
# Current generation 306, best score 1518957.000000, pop. avg. 1593937.700000
# ..................................................
# Current generation 307, best score 1518957.000000, pop. avg. 1580489.860000
# ..................................................
# Current generation 308, best score 1518502.000000, pop. avg. 1569270.360000
# ..................................................
# Current generation 309, best score 1518264.000000, pop. avg. 1588435.480000
# ..................................................
# Current generation 310, best score 1518211.000000, pop. avg. 1627368.840000
# ..................................................
# Current generation 311, best score 1518211.000000, pop. avg. 1587879.580000
# ..................................................
# Current generation 312, best score 1518182.000000, pop. avg. 1623344.240000
# ..................................................
# Current generation 313, best score 1518138.000000, pop. avg. 1596769.580000
# ..................................................
# Current generation 314, best score 1518368.000000, pop. avg. 1582302.020000
# ..................................................
# Current generation 315, best score 1517061.000000, pop. avg. 1569692.260000
# ..................................................
# Current generation 316, best score 1517105.000000, pop. avg. 1559534.800000
# ..................................................
# Current generation 317, best score 1517105.000000, pop. avg. 1570432.100000
# ..................................................
# Current generation 318, best score 1517228.000000, pop. avg. 1592415.100000
# ..................................................
# Current generation 319, best score 1517228.000000, pop. avg. 1667227.760000
# ..................................................
# Current generation 320, best score 1517192.000000, pop. avg. 1584705.840000
# ..................................................
# Current generation 321, best score 1517007.000000, pop. avg. 1580913.640000
# ..................................................
# Current generation 322, best score 1511331.000000, pop. avg. 1574436.460000
# ..................................................
# Current generation 323, best score 1511044.000000, pop. avg. 1612502.740000
# ..................................................
# Current generation 324, best score 1508936.000000, pop. avg. 1572962.700000
# ..................................................
# Current generation 325, best score 1508656.000000, pop. avg. 1580810.760000
# ..................................................
# Current generation 326, best score 1508656.000000, pop. avg. 1601356.620000
# ..................................................
# Current generation 327, best score 1508656.000000, pop. avg. 1592267.060000
# ..................................................
# Current generation 328, best score 1508560.000000, pop. avg. 1607888.200000
# ..................................................
# Current generation 329, best score 1507396.000000, pop. avg. 1581826.620000
# ..................................................
# Current generation 330, best score 1507025.000000, pop. avg. 1580663.020000
# ..................................................
# Current generation 331, best score 1507025.000000, pop. avg. 1609870.340000
# ..................................................
# Current generation 332, best score 1506948.000000, pop. avg. 1582681.100000
# ..................................................
# Current generation 333, best score 1505961.000000, pop. avg. 1595247.160000
# ..................................................
# Current generation 334, best score 1505843.000000, pop. avg. 1577266.480000
# ..................................................
# Current generation 335, best score 1503921.000000, pop. avg. 1578757.500000
# ..................................................
# Current generation 336, best score 1503921.000000, pop. avg. 1579752.340000
# ..................................................
# Current generation 337, best score 1502663.000000, pop. avg. 1549890.480000
# ..................................................
# Current generation 338, best score 1501753.000000, pop. avg. 1563276.420000
# ..................................................
# Current generation 339, best score 1501678.000000, pop. avg. 1554749.540000
# ..................................................
# Current generation 340, best score 1502177.000000, pop. avg. 1575486.900000
# ..................................................
# Current generation 341, best score 1502023.000000, pop. avg. 1571658.320000
# ..................................................
# Current generation 342, best score 1502061.000000, pop. avg. 1588434.260000
# ..................................................
# Current generation 343, best score 1501654.000000, pop. avg. 1559029.940000
# ..................................................
# Current generation 344, best score 1501557.000000, pop. avg. 1564353.340000
# ..................................................
# Current generation 345, best score 1501299.000000, pop. avg. 1571768.380000
# ..................................................
# Current generation 346, best score 1501299.000000, pop. avg. 1590209.260000
# ..................................................
# Current generation 347, best score 1500664.000000, pop. avg. 1584749.640000
# ..................................................
# Current generation 348, best score 1498105.000000, pop. avg. 1562021.580000
# ..................................................
# Current generation 349, best score 1498105.000000, pop. avg. 1564509.640000
# ..................................................
# Current generation 350, best score 1498105.000000, pop. avg. 1545817.300000
# ..................................................
# Current generation 351, best score 1497826.000000, pop. avg. 1561391.840000
# ..................................................
# Current generation 352, best score 1497826.000000, pop. avg. 1587384.420000
# ..................................................
# Current generation 353, best score 1497576.000000, pop. avg. 1602200.780000
# ..................................................
# Current generation 354, best score 1497763.000000, pop. avg. 1565239.200000
# ..................................................
# Current generation 355, best score 1497449.000000, pop. avg. 1550687.060000
# ..................................................
# Current generation 356, best score 1497308.000000, pop. avg. 1563629.100000
# ..................................................
# Current generation 357, best score 1497308.000000, pop. avg. 1559331.080000
# ..................................................
# Current generation 358, best score 1497308.000000, pop. avg. 1586593.780000
# ..................................................
# Current generation 359, best score 1497308.000000, pop. avg. 1600264.360000
# ..................................................
# Current generation 360, best score 1497308.000000, pop. avg. 1538035.760000
# ..................................................
# Current generation 361, best score 1497074.000000, pop. avg. 1552087.560000
# ..................................................
# Current generation 362, best score 1496573.000000, pop. avg. 1549497.260000
# ..................................................
# Current generation 363, best score 1496817.000000, pop. avg. 1573430.220000
# ..................................................
# Current generation 364, best score 1496786.000000, pop. avg. 1580030.060000
# ..................................................
# Current generation 365, best score 1496577.000000, pop. avg. 1569953.960000
# ..................................................
# Current generation 366, best score 1496577.000000, pop. avg. 1575414.280000
# ..................................................
# Current generation 367, best score 1496577.000000, pop. avg. 1566572.260000
# ..................................................
# Current generation 368, best score 1496337.000000, pop. avg. 1591294.700000
# ..................................................
# Current generation 369, best score 1496174.000000, pop. avg. 1609436.920000
# ..................................................
# Current generation 370, best score 1496161.000000, pop. avg. 1561989.460000
# ..................................................
# Current generation 371, best score 1496112.000000, pop. avg. 1554891.500000
# ..................................................
# Current generation 372, best score 1496125.000000, pop. avg. 1573392.080000
# ..................................................
# Current generation 373, best score 1496125.000000, pop. avg. 1570962.380000
# ..................................................
# Current generation 374, best score 1495902.000000, pop. avg. 1548002.380000
# ..................................................
# Current generation 375, best score 1496129.000000, pop. avg. 1639634.100000
# ..................................................
# Current generation 376, best score 1495975.000000, pop. avg. 1566988.140000
# ..................................................
# Current generation 377, best score 1495975.000000, pop. avg. 1584315.300000
# ..................................................
# Current generation 378, best score 1495894.000000, pop. avg. 1560464.700000
# ..................................................
# Current generation 379, best score 1495783.000000, pop. avg. 1602012.460000
# ..................................................
# Current generation 380, best score 1495526.000000, pop. avg. 1564419.140000
# ..................................................
# Current generation 381, best score 1495526.000000, pop. avg. 1587016.260000
# ..................................................
# Current generation 382, best score 1495888.000000, pop. avg. 1610226.120000
# ..................................................
# Current generation 383, best score 1495238.000000, pop. avg. 1577247.240000
# ..................................................
# Current generation 384, best score 1495173.000000, pop. avg. 1577067.120000
# ..................................................
# Current generation 385, best score 1495173.000000, pop. avg. 1550039.980000
# ..................................................
# Current generation 386, best score 1494921.000000, pop. avg. 1547072.120000
# ..................................................
# Current generation 387, best score 1494843.000000, pop. avg. 1586208.020000
# ..................................................
# Current generation 388, best score 1494843.000000, pop. avg. 1550168.620000
# ..................................................
# Current generation 389, best score 1493378.000000, pop. avg. 1562274.000000
# ..................................................
# Current generation 390, best score 1493332.000000, pop. avg. 1591747.900000
# ..................................................
# Current generation 391, best score 1493341.000000, pop. avg. 1553885.480000
# ..................................................
# Current generation 392, best score 1493382.000000, pop. avg. 1576542.980000
# ..................................................
# Current generation 393, best score 1493111.000000, pop. avg. 1574190.440000
# ..................................................
# Current generation 394, best score 1493129.000000, pop. avg. 1568830.480000
# ..................................................
# Current generation 395, best score 1492950.000000, pop. avg. 1607317.820000
# ..................................................
# Current generation 396, best score 1492950.000000, pop. avg. 1546950.880000
# ..................................................
# Current generation 397, best score 1492950.000000, pop. avg. 1596769.020000
# ..................................................
# Current generation 398, best score 1493110.000000, pop. avg. 1563234.340000
# ..................................................
# Current generation 399, best score 1493002.000000, pop. avg. 1571965.580000
# ..................................................
# Current generation 400, best score 1493002.000000, pop. avg. 1599477.580000
# ..................................................
# Current generation 401, best score 1493124.000000, pop. avg. 1565984.240000
# ..................................................
# Current generation 402, best score 1492867.000000, pop. avg. 1560847.720000
# ..................................................
# Current generation 403, best score 1493166.000000, pop. avg. 1594985.680000
# ..................................................
# Current generation 404, best score 1492996.000000, pop. avg. 1580469.520000
# ..................................................
# Current generation 405, best score 1492499.000000, pop. avg. 1567217.760000
# ..................................................
# Current generation 406, best score 1492499.000000, pop. avg. 1547087.900000
# ..................................................
# Current generation 407, best score 1492499.000000, pop. avg. 1542072.740000
# ..................................................
# Current generation 408, best score 1492180.000000, pop. avg. 1556412.100000
# ..................................................
# Current generation 409, best score 1492264.000000, pop. avg. 1590921.440000
# ..................................................
# Current generation 410, best score 1492264.000000, pop. avg. 1615726.220000
# ..................................................
# Current generation 411, best score 1492264.000000, pop. avg. 1550161.300000
# ..................................................
# Current generation 412, best score 1491870.000000, pop. avg. 1545591.660000
# ..................................................
# Current generation 413, best score 1485584.000000, pop. avg. 1537182.020000
# ..................................................
# Current generation 414, best score 1485584.000000, pop. avg. 1580697.140000
# ..................................................
# Current generation 415, best score 1485584.000000, pop. avg. 1575784.640000
# ..................................................
# Current generation 416, best score 1485459.000000, pop. avg. 1585265.480000
# ..................................................
# Current generation 417, best score 1485444.000000, pop. avg. 1558551.200000
# ..................................................
# Current generation 418, best score 1485471.000000, pop. avg. 1559729.660000
# ..................................................
# Current generation 419, best score 1485478.000000, pop. avg. 1573192.120000
# ..................................................
# Current generation 420, best score 1485478.000000, pop. avg. 1535556.460000
# ..................................................
# Current generation 421, best score 1485478.000000, pop. avg. 1566405.300000
# ..................................................
# Current generation 422, best score 1485402.000000, pop. avg. 1547949.800000
# ..................................................
# Current generation 423, best score 1485368.000000, pop. avg. 1558280.360000
# ..................................................
# Current generation 424, best score 1477926.000000, pop. avg. 1586526.400000
# ..................................................
# Current generation 425, best score 1478102.000000, pop. avg. 1572721.040000
# ..................................................
# Current generation 426, best score 1478108.000000, pop. avg. 1604381.920000
# ..................................................
# Current generation 427, best score 1477892.000000, pop. avg. 1528117.520000
# ..................................................
# Current generation 428, best score 1477892.000000, pop. avg. 1549085.180000
# ..................................................
# Current generation 429, best score 1477892.000000, pop. avg. 1556256.160000
# ..................................................
# Current generation 430, best score 1477892.000000, pop. avg. 1549033.940000
# ..................................................
# Current generation 431, best score 1478084.000000, pop. avg. 1576746.360000
# ..................................................
# Current generation 432, best score 1477847.000000, pop. avg. 1559423.520000
# ..................................................
# Current generation 433, best score 1477655.000000, pop. avg. 1525520.880000
# ..................................................
# Current generation 434, best score 1477655.000000, pop. avg. 1549567.680000
# ..................................................
# Current generation 435, best score 1477484.000000, pop. avg. 1565357.260000
# ..................................................
# Current generation 436, best score 1477484.000000, pop. avg. 1569793.080000
# ..................................................
# Current generation 437, best score 1477484.000000, pop. avg. 1586937.720000
# ..................................................
# Current generation 438, best score 1477425.000000, pop. avg. 1551069.500000
# ..................................................
# Current generation 439, best score 1477785.000000, pop. avg. 1576931.620000
# ..................................................
# Current generation 440, best score 1476110.000000, pop. avg. 1532006.600000
# ..................................................
# Current generation 441, best score 1476110.000000, pop. avg. 1569792.260000
# ..................................................
# Current generation 442, best score 1476108.000000, pop. avg. 1578979.840000
# ..................................................
# Current generation 443, best score 1476108.000000, pop. avg. 1595162.140000
# ..................................................
# Current generation 444, best score 1476114.000000, pop. avg. 1535870.460000
# ..................................................
# Current generation 445, best score 1476114.000000, pop. avg. 1570294.840000
# ..................................................
# Current generation 446, best score 1476114.000000, pop. avg. 1532265.980000
# ..................................................
# Current generation 447, best score 1476114.000000, pop. avg. 1519348.620000
# ..................................................
# Current generation 448, best score 1476066.000000, pop. avg. 1565487.080000
# ..................................................
# Current generation 449, best score 1476066.000000, pop. avg. 1545873.580000
# ..................................................
# Current generation 450, best score 1476066.000000, pop. avg. 1564752.640000
# ..................................................
# Current generation 451, best score 1476066.000000, pop. avg. 1543298.060000
# ..................................................
# Current generation 452, best score 1476066.000000, pop. avg. 1582534.680000
# ..................................................
# Current generation 453, best score 1475931.000000, pop. avg. 1537238.360000
# ..................................................
# Current generation 454, best score 1475931.000000, pop. avg. 1565993.680000
# ..................................................
# Current generation 455, best score 1473344.000000, pop. avg. 1577134.280000
# ..................................................
# Current generation 456, best score 1473260.000000, pop. avg. 1557573.480000
# ..................................................
# Current generation 457, best score 1473171.000000, pop. avg. 1553872.100000
# ..................................................
# Current generation 458, best score 1472816.000000, pop. avg. 1523211.680000
# ..................................................
# Current generation 459, best score 1472816.000000, pop. avg. 1551925.600000
# ..................................................
# Current generation 460, best score 1472816.000000, pop. avg. 1552604.980000
# ..................................................
# Current generation 461, best score 1472784.000000, pop. avg. 1548460.040000
# ..................................................
# Current generation 462, best score 1472467.000000, pop. avg. 1591788.160000
# ..................................................
# Current generation 463, best score 1472575.000000, pop. avg. 1540643.760000
# ..................................................
# Current generation 464, best score 1472385.000000, pop. avg. 1556363.140000
# ..................................................
# Current generation 465, best score 1472409.000000, pop. avg. 1552612.300000
# ..................................................
# Current generation 466, best score 1472323.000000, pop. avg. 1567215.680000
# ..................................................
# Current generation 467, best score 1472323.000000, pop. avg. 1535111.740000
# ..................................................
# Current generation 468, best score 1472528.000000, pop. avg. 1583200.700000
# ..................................................
# Current generation 469, best score 1472361.000000, pop. avg. 1544275.440000
# ..................................................
# Current generation 470, best score 1472396.000000, pop. avg. 1538711.800000
# ..................................................
# Current generation 471, best score 1468078.000000, pop. avg. 1535701.300000
# ..................................................
# Current generation 472, best score 1467771.000000, pop. avg. 1588242.300000
# ..................................................
# Current generation 473, best score 1467708.000000, pop. avg. 1549322.600000
# ..................................................
# Current generation 474, best score 1467708.000000, pop. avg. 1546396.020000
# ..................................................
# Current generation 475, best score 1467522.000000, pop. avg. 1544223.360000
# ..................................................
# Current generation 476, best score 1467316.000000, pop. avg. 1567303.800000
# ..................................................
# Current generation 477, best score 1467316.000000, pop. avg. 1540674.880000
# ..................................................
# Current generation 478, best score 1465729.000000, pop. avg. 1563919.820000
# ..................................................
# Current generation 479, best score 1465729.000000, pop. avg. 1540417.960000
# ..................................................
# Current generation 480, best score 1465729.000000, pop. avg. 1537302.640000
# ..................................................
# Current generation 481, best score 1465014.000000, pop. avg. 1518437.720000
# ..................................................
# Current generation 482, best score 1464773.000000, pop. avg. 1562931.380000
# ..................................................
# Current generation 483, best score 1464773.000000, pop. avg. 1553096.240000
# ..................................................
# Current generation 484, best score 1464773.000000, pop. avg. 1535344.120000
# ..................................................
# Current generation 485, best score 1464728.000000, pop. avg. 1522346.820000
# ..................................................
# Current generation 486, best score 1464728.000000, pop. avg. 1549092.560000
# ..................................................
# Current generation 487, best score 1464728.000000, pop. avg. 1496321.220000
# ..................................................
# Current generation 488, best score 1464544.000000, pop. avg. 1566265.680000
# ..................................................
# Current generation 489, best score 1464544.000000, pop. avg. 1546824.520000
# ..................................................
# Current generation 490, best score 1464544.000000, pop. avg. 1527312.840000
# ..................................................
# Current generation 491, best score 1464319.000000, pop. avg. 1546853.460000
# ..................................................
# Current generation 492, best score 1464319.000000, pop. avg. 1534784.340000
# ..................................................
# Current generation 493, best score 1464210.000000, pop. avg. 1569920.160000
# ..................................................
# Current generation 494, best score 1464210.000000, pop. avg. 1521510.880000
# ..................................................
# Current generation 495, best score 1464200.000000, pop. avg. 1531693.440000
# ..................................................
# Current generation 496, best score 1464187.000000, pop. avg. 1558769.540000
# ..................................................
# Current generation 497, best score 1464111.000000, pop. avg. 1522554.760000
# ..................................................
# Current generation 498, best score 1464149.000000, pop. avg. 1525316.620000
# ..................................................
# Current generation 499, best score 1464078.000000, pop. avg. 1530532.300000
# ..................................................
# Current generation 500, best score 1463993.000000, pop. avg. 1557136.840000
